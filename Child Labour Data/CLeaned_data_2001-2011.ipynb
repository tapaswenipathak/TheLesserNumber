# %%
import plotly as pd
import plotly.graph_objs as go
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

# %%
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
import pandas as pd
df = pd.read_excel('Census-2001&2011.xlsx')
df
# Out:
#    State wise details of working children in the age group of 5-14 years as per Census\n2001 and Census 2011 are as under:  ... Unnamed: 4
# 0                                             Sl. No.                                                                       ...        NaN
# 1                                                 NaN                                                                       ...        NaN
# 2                                                   1                                                                       ...        NaN
# 3                                                   2                                                                       ...        NaN
# 4                                                   3                                                                       ...        NaN
# 5                                                   4                                                                       ...        NaN
# ...

# %%
df = df.drop(df.columns[4], axis=1)

# %%
df.columns = ['SNo', 'Name of State/UT' ,'No. of working children in the age group of 5-14 Census 2001', 'No. of working children in the age group of 5-14 Census 2011']

# %%
df = df.drop(df.index[[0,1,37,38]])

# %%
df = df.reset_index(drop=True)

# %%
df
# Out:
#    SNo  ... No. of working children in the age group of 5-14 Census 2011
# 0    1  ...                                                999
# 1    2  ...                                             404851
# 2    3  ...                                               5766
# 3    4  ...                                              99512
# 4    5  ...                                             451590
# 5    6  ...                                               3135
# 6    7  ...                                              63884
# 7    8  ...                                               1054
# 8    9  ...                                                774
# 9   10  ...                                              26473
# 10  11  ...                                               6920
# 11  12  ...                                             250318
# 12  13  ...                                              53492
# 13  14  ...                                              15001
# ...
