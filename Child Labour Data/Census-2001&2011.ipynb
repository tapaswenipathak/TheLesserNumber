# %%
import pandas as pd

# %%
df = pd.read_excel('Census-2001&2011.xlsx')

# %%
df
# Out:
#    State wise details of working children in the age group of 5-14 years as per Census\n2001 and Census 2011 are as under:  \
# 0                                             Sl. No.
# 1                                                 NaN
# 2                                                   1
# 3                                                   2
# 4                                                   3
# 5                                                   4
# 6                                                   5
# 7                                                   6
# 8                                                   7
# 9                                                   8
# 10                                                  9
# 11                                                 10
# 12                                                 11
# 13                                                 12
# 14                                                 13
# ...

# %%
# Deleting the last coloumn

# %%
df = df.drop(df.columns[4], axis=1)

# %%
df
# Out:
#    State wise details of working children in the age group of 5-14 years as per Census\n2001 and Census 2011 are as under:  \
# 0                                             Sl. No.
# 1                                                 NaN
# 2                                                   1
# 3                                                   2
# 4                                                   3
# 5                                                   4
# 6                                                   5
# 7                                                   6
# 8                                                   7
# 9                                                   8
# 10                                                  9
# 11                                                 10
# 12                                                 11
# 13                                                 12
# 14                                                 13
# ...

# %%
df.columns = ['SNo', 'Name of State/UT', 'No. of working children in the age group of 5-14 in Census 2001', 'No. of working children in the age group of 5-14 in Census 2011']

# %%
df
# Out:
#         SNo          Name of State/UT  \
# 0   Sl. No.          Name of State/UT
# 1       NaN                       NaN
# 2         1  Andaman & Nicobar Island
# 3         2            Andhra Pradesh
# 4         3         Arunachal Pradesh
# 5         4                     Assam
# 6         5                     Bihar
# 7         6        Chandigarh    U.T.
# 8         7              Chhattisgarh
# 9         8          Dadra & Nagar H.
# 10        9          Daman & Diu U.T.
# 11       10                Delhi U.T.
# 12       11                       Goa
# 13       12                   Gujarat
# 14       13                   Haryana
# 15       14          Himachal Pradesh
# 16       15           Jammu & Kashmir
# 17       16                 Jharkhand
# 18       17                 Karnataka
# 19       18                    Kerala
# 20       19            Lakshadweep UT
# 21       20            Madhya Pradesh
# 22       21               Maharashtra
# ...

# %%
df = df.drop(df.index[[0,1]])

# %%
df
# Out:
#     SNo          Name of State/UT  \
# 2     1  Andaman & Nicobar Island
# 3     2            Andhra Pradesh
# 4     3         Arunachal Pradesh
# 5     4                     Assam
# 6     5                     Bihar
# 7     6        Chandigarh    U.T.
# 8     7              Chhattisgarh
# 9     8          Dadra & Nagar H.
# 10    9          Daman & Diu U.T.
# 11   10                Delhi U.T.
# 12   11                       Goa
# 13   12                   Gujarat
# 14   13                   Haryana
# 15   14          Himachal Pradesh
# 16   15           Jammu & Kashmir
# 17   16                 Jharkhand
# 18   17                 Karnataka
# 19   18                    Kerala
# 20   19            Lakshadweep UT
# 21   20            Madhya Pradesh
# 22   21               Maharashtra
# 23   22                   Manipur
# 24   23                 Meghalaya
# 25   24                   Mizoram
# 26   25                  Nagaland
# 27   26                    Odisha
# ...

# %%
df = df.reset_index(drop=True)

# %%
df
# Out:
#     SNo          Name of State/UT  \
# 0     1  Andaman & Nicobar Island
# 1     2            Andhra Pradesh
# 2     3         Arunachal Pradesh
# 3     4                     Assam
# 4     5                     Bihar
# 5     6        Chandigarh    U.T.
# 6     7              Chhattisgarh
# 7     8          Dadra & Nagar H.
# 8     9          Daman & Diu U.T.
# 9    10                Delhi U.T.
# 10   11                       Goa
# 11   12                   Gujarat
# 12   13                   Haryana
# 13   14          Himachal Pradesh
# 14   15           Jammu & Kashmir
# 15   16                 Jharkhand
# 16   17                 Karnataka
# 17   18                    Kerala
# 18   19            Lakshadweep UT
# 19   20            Madhya Pradesh
# 20   21               Maharashtra
# 21   22                   Manipur
# 22   23                 Meghalaya
# 23   24                   Mizoram
# 24   25                  Nagaland
# 25   26                    Odisha
# ...

# %%
df = df.drop(df.index[36])

# %%
df
# Out:
#     SNo          Name of State/UT  \
# 0     1  Andaman & Nicobar Island
# 1     2            Andhra Pradesh
# 2     3         Arunachal Pradesh
# 3     4                     Assam
# 4     5                     Bihar
# 5     6        Chandigarh    U.T.
# 6     7              Chhattisgarh
# 7     8          Dadra & Nagar H.
# 8     9          Daman & Diu U.T.
# 9    10                Delhi U.T.
# 10   11                       Goa
# 11   12                   Gujarat
# 12   13                   Haryana
# 13   14          Himachal Pradesh
# 14   15           Jammu & Kashmir
# 15   16                 Jharkhand
# 16   17                 Karnataka
# 17   18                    Kerala
# 18   19            Lakshadweep UT
# 19   20            Madhya Pradesh
# 20   21               Maharashtra
# 21   22                   Manipur
# 22   23                 Meghalaya
# 23   24                   Mizoram
# 24   25                  Nagaland
# 25   26                    Odisha
# ...

# %%
df.xs(35)['SNo'] = ''

# %%
df
# Out:
#    SNo          Name of State/UT  \
# 0    1  Andaman & Nicobar Island
# 1    2            Andhra Pradesh
# 2    3         Arunachal Pradesh
# 3    4                     Assam
# 4    5                     Bihar
# 5    6        Chandigarh    U.T.
# 6    7              Chhattisgarh
# 7    8          Dadra & Nagar H.
# 8    9          Daman & Diu U.T.
# 9   10                Delhi U.T.
# 10  11                       Goa
# 11  12                   Gujarat
# 12  13                   Haryana
# 13  14          Himachal Pradesh
# 14  15           Jammu & Kashmir
# 15  16                 Jharkhand
# 16  17                 Karnataka
# 17  18                    Kerala
# 18  19            Lakshadweep UT
# 19  20            Madhya Pradesh
# 20  21               Maharashtra
# 21  22                   Manipur
# 22  23                 Meghalaya
# 23  24                   Mizoram
# 24  25                  Nagaland
# 25  26                    Odisha
# 26  27        Pondicherry   U.T.
# ...

# %%
import matplotlib.pyplot as plt

# %%
df = df.drop(df.index[35])

# %%
ax = plt.gca()

df.plot(kind='bar',x='Name of State/UT',y='No. of working children in the age group of 5-14 in Census 2001',ax=ax)
plt.show()

# %%
ax = plt.gca()
df.plot(kind='bar',x='Name of State/UT',y='No. of working children in the age group of 5-14 in Census 2011',ax=ax)
plt.show()
