# %%
import pandas as pd

# %%
df = pd.read_excel('Census1971to2001.xlsx')

# %%
df
# Out:
#    State-wise Distribution of Working Children according to 1971,1981, 1991 and \n2001 Census in the age group 5-14 years  \
# 0                                               S.No.
# 1                                                 NaN
# 2                                                   1
# 3                                                   2
# 4                                                   3
# 5                                                   4
# 6                                                   5
# 7                                                   6
# 8                                                   7
# 9                                                   8
# 10                                                  9
# 11                                                 10
# 12                                                 11
# 13                                                 12
# 14                                                 13
# ...

# %%
df.at[1, 'Name of the State/UT'] = 'Assam'

# %%
df = df.drop(df.columns[6], axis=1)

# %%
df.columns = ['SNo', 'Name of the State/UT', '1971', '1981', '1991', '2001']

# %%
df = df.drop(df.index[[0,1,37,38]])
df = df.reset_index(drop=True)

# %%
df.at[33, 'Name of the State/UT'] = 'Mizoram'

# %%
import numpy as np

# %%
df = df.replace(np.NaN, 0)

# %%
df
# Out:
#     SNo      Name of the State/UT       1971     1981                  1991  \
# 0     1            Andhra Pradesh  1627492.0  1951312               1661940
# 1     2                     Assam   239349.0        0                327598
# 2     3                     Bihar  1059359.0  1101764                942245
# 3     4                   Gujarat   518061.0   616913                523585
# 4     5                   Haryana   137826.0   194189                109691
# 5     6          Himachal Pradesh    71384.0    99624                 56438
# 6     7           Jammu & Kashmir    70489.0   258437                    **
# 7     8                 Karnataka   808719.0  1131530                976247
# 8     9                    Kerala   111801.0    92854                 34800
# 9    10            Madhya Pradesh  1112319.0  1698597               1352563
# 10   11               Maharashtra   988357.0  1557756               1068427
# ...

# %%
df.at[6, '1991'] = 0

# %%
df.at[18, '2001'] = 177268

# %%
df.at[18, '1991'] = 142868

# %%
df
# Out:
#     SNo      Name of the State/UT       1971     1981     1991     2001
# 0     1            Andhra Pradesh  1627492.0  1951312  1661940  1363339
# 1     2                     Assam   239349.0        0   327598   351416
# 2     3                     Bihar  1059359.0  1101764   942245  1117500
# 3     4                   Gujarat   518061.0   616913   523585   485530
# 4     5                   Haryana   137826.0   194189   109691   253491
# 5     6          Himachal Pradesh    71384.0    99624    56438   107774
# 6     7           Jammu & Kashmir    70489.0   258437        0   175630
# 7     8                 Karnataka   808719.0  1131530   976247   822615
# 8     9                    Kerala   111801.0    92854    34800    26156
# 9    10            Madhya Pradesh  1112319.0  1698597  1352563  1065259
# 10   11               Maharashtra   988357.0  1557756  1068427   764075
# 11   12              Chhattisgarh        0.0        0        0   364572
# ...

# %%
import matplotlib.pyplot as plt

# %%
ax = plt.gca()
i = 0 
for name, values in df.iteritems():
    if i == 0 or i == 1:
        pass
    else:
        ax = plt.gca()
        df.plot(kind='bar', x='Name of the State/UT', y='{name}'.format(name=name), ax=ax)
        plt.show()
    i=i+1
i=0
